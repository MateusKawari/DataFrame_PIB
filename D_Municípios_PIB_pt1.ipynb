# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusKawari/DataFrame_PIB/blob/main/D_Munic%C3%ADpios_PIB_pt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Começando os primeiros treinos com Pandas, analisando os respectivos dados
# Algumas perguntas devem ser feitas assim que analisar estes dados.

# %%
import pandas as pd

# %%
dfMun = pd.read_csv('/content/PIB_MUNICIPIOS_BR.csv.csv')

# %%
dfMun
# Out:
#    Municípios e respectivas\nUnidades da Federação  \
# 0                                   São Paulo (SP)
# 1                              Rio de Janeiro (RJ)
# 2                                    Brasília (DF)
# 3                              Belo Horizonte (MG)
# 4                                      Manaus (AM)
# ..                                             ...
# 95                                  Americana (SP)
# 96                                  Paranaguá (PR)
# 97                                    Chapecó (SC)
# 98                     São Francisco do Conde (BA)
# 99                                  Rio Verde (GO)
#
#    Posição ocu-\npada pelos\n100 maiores\nmunicípios  \
# 0                                                 1º
# 1                                                 2º
# 2                                                 3º
# 3                                                 4º
# 4                                                 5º
# ...

# %%
#Vendo os 10 primeiros dados
dfMun.head(10)
# Out:
#   Municípios e respectivas\nUnidades da Federação  \
# 0                                  São Paulo (SP)
# 1                             Rio de Janeiro (RJ)
# 2                                   Brasília (DF)
# 3                             Belo Horizonte (MG)
# 4                                     Manaus (AM)
# 5                                   Curitiba (PR)
# 6                                     Osasco (SP)
# 7                               Porto Alegre (RS)
# 8                                  Guarulhos (SP)
# 9                                   Campinas (SP)
#
#   Posição ocu-\npada pelos\n100 maiores\nmunicípios  \
# 0                                                1º
# 1                                                2º
# 2                                                3º
# 3                                                4º
# 4                                                5º
# 5                                                6º
# ...

# %%
# Vendo os 10 últimos
dfMun.tail(10)
# Out:
#    Municípios e respectivas\nUnidades da Federação  \
# 90                                     Suzano (SP)
# 91                                 Vila Velha (ES)
# 92                                    Itapevi (SP)
# 93                                  Nova Lima (MG)
# 94                                 São Carlos (SP)
# 95                                  Americana (SP)
# 96                                  Paranaguá (PR)
# 97                                    Chapecó (SC)
# 98                     São Francisco do Conde (BA)
# 99                                  Rio Verde (GO)
#
#    Posição ocu-\npada pelos\n100 maiores\nmunicípios  \
# 90                                               91º
# 91                                               92º
# 92                                               93º
# 93                                               94º
# 94                                               95º
# 95                                               96º
# ...

# %%
''' O presente dataframe mostra os municípios que renderam maior produto interno bruto nos preços correntes, sua participação
em ranking.

Podemos elaborar perguntas básicas que podem ser respondidas analisando estes dados, tais como:

Há uma relação de posição, PIB municipal com município capital ? Será que os municípios próximos a capital do estado
apresentam melhores resultados ?

Há alguma relação entre as regiões do país e o PIB arrecadado ?

Qual a relação entre os 10 primeiros municípios ? E os 10 últimos, há alguma relação de região ? '''
